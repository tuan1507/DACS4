# %%
import os
from PIL import Image
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_dir = "Data/train"
data = []

for label in os.listdir(data_dir):
    label_path = os.path.join(data_dir, label)
    if os.path.isdir(label_path):
        for img_file in os.listdir(label_path):
            img_path = os.path.join(label_path, img_file)
            try:
                img = Image.open(img_path).convert("RGB")
                r, g, b = img.resize((1, 1)).getpixel((0, 0))  # Resize để lấy màu trung bình
                data.append({"label": label, "R": r, "G": g, "B": b})
            except Exception as e:
                print(f"Không thể xử lý tệp: {img_path}, lỗi: {e}")

df = pd.DataFrame(data)
print(df.head())
# Out:
#    label  R    G    B
# 0  black  0    0  255
# 1  black  0   51  119
# 2  black  0   72  186
# 3  black  0  117  179
# 4  black  0  119  179

# %%
sns.countplot(data=df, x='label', palette='Set2')
plt.title("Phân bố số lượng mẫu theo nhãn")
plt.show()
# Out:
# C:\Users\HELIOS 300\AppData\Local\Temp\ipykernel_16564\55838270.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='label', palette='Set2')
